# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline 
sns.set()

# %%
df = pd.read_csv('C:\\Users\\DELL\\Documents\\my_data\\700 Classic Disco Tracks (with Spotify Data)\\ClassicDisco.csv')

# %% [markdown]
# # exploring data

# %%
df.head(10)
# Out:
#                                Track            Artist  \
# 0                 Boogie Oogie Oogie  A Taste Of Honey
# 1  Disco Dancin' - 2004 - Remastered  A Taste Of Honey
# 2                            Distant  A Taste Of Honey
# 3                         Do It Good  A Taste Of Honey
# 4                        If We Loved  A Taste Of Honey
# 5             Rescue Me - Remastered  A Taste Of Honey
# 6                           Sky High  A Taste Of Honey
# 7                  This Love Of Ours  A Taste Of Honey
# 8                         World Spin  A Taste Of Honey
# 9                         Chiquitita              ABBA
#
#                               Album  Year  Duration  Time_Signature  \
# 0                  A Taste Of Honey  1978    245173               4
# 1                  A Taste Of Honey  1978    210493               4
# 2                  A Taste Of Honey  1978    260053               4
# 3  Another Taste (Expanded Edition)  1978    342826               4
# ...

# %%
df.tail()
# Out:
#                Track  Artist                                      Album  Year  \
# 719     Lady America  Voyage  Twelve Inch Classics from the 70s, Vol. 2  1979
# 720   Let's Fly Away  Voyage                                   Fly Away  1979
# 721   Scotch Machine  Voyage                                     Voyage  1979
# 722        Souvenirs  Voyage                                   Fly Away  1979
# 723  Tahiti, Tahiti…  Voyage                                   Fly Away  1979
#
#      Duration  Time_Signature  Danceability  Energy  Key  Loudness  Mode  \
# 719    407800               4         0.649   0.840    5    -7.713     1
# 720    306818               4         0.709   0.854    8    -4.750     1
# 721    208200               4         0.633   0.901   10   -10.248     1
# 722    390567               4         0.633   0.970    5    -4.153     1
# 723    299510               4         0.672   0.972    2    -4.929     1
#
# ...

# %% [markdown]
# # some information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 724 entries, 0 to 723
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track             724 non-null    object
#  1   Artist            724 non-null    object
#  2   Album             724 non-null    object
#  3   Year              724 non-null    int64
#  4   Duration          724 non-null    int64
#  5   Time_Signature    724 non-null    int64
#  6   Danceability      724 non-null    float64
#  7   Energy            724 non-null    float64
#  8   Key               724 non-null    int64
#  9   Loudness          724 non-null    float64
#  10  Mode              724 non-null    int64
#  11  Speechiness       724 non-null    float64
#  12  Acousticness      724 non-null    float64
#  13  Instrumentalness  724 non-null    float64
#  14  Liveness          724 non-null    float64
#  15  Valence           724 non-null    float64
# ...

# %% [markdown]
# # checking for null values

# %%
df.isna().sum()
# Out:
# Track               0
# Artist              0
# Album               0
# Year                0
# Duration            0
# Time_Signature      0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Popularity          0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#               Year      Duration  Time_Signature  Danceability      Energy  \
# count   724.000000  7.240000e+02      724.000000    724.000000  724.000000
# mean   1977.872928  3.013971e+05        3.970994      0.691912    0.665481
# std       4.126678  1.000937e+05        0.175981      0.127139    0.176193
# min    1967.000000  1.270530e+05        3.000000      0.293000    0.034800
# 25%    1976.000000  2.306595e+05        4.000000      0.618750    0.549750
# 50%    1978.000000  2.808165e+05        4.000000      0.708000    0.689000
# 75%    1980.000000  3.534562e+05        4.000000      0.784000    0.805750
# max    2020.000000  1.008533e+06        5.000000      0.980000    0.985000
#
#               Key    Loudness        Mode  Speechiness  Acousticness  \
# count  724.000000  724.000000  724.000000   724.000000    724.000000
# mean     5.356354  -10.043793    0.574586     0.060252      0.193440
# std      3.741299    3.130664    0.494747     0.038666      0.217953
# ...

# %%
df.groupby(by = 'Year').describe().round()
# Out:
#      Duration                                                              \
#         count      mean       std       min       25%       50%       75%
# Year
# 1967      2.0  155933.0   11785.0  147600.0  151766.0  155933.0  160100.0
# 1969      4.0  237683.0   90192.0  169293.0  190983.0  205620.0  252320.0
# 1970      6.0  289127.0  144261.0  165789.0  183816.0  265360.0  312403.0
# 1971      7.0  203644.0   34771.0  181226.0  185820.0  187306.0  203066.0
# 1972     16.0  259576.0   94125.0  170741.0  188123.0  221980.0  291123.0
# 1973     32.0  283202.0  102720.0  127053.0  212163.0  255100.0  363080.0
# 1974     37.0  281233.0  103000.0  158762.0  222346.0  252666.0  288440.0
# 1975     67.0  289586.0  124655.0  161813.0  208320.0  250773.0  344666.0
# 1976     76.0  276401.0  101516.0  170000.0  204960.0  240986.0  334766.0
# 1977     67.0  309535.0  103626.0  160906.0  243560.0  289133.0  337873.0
# 1978    117.0  320624.0  107167.0  186792.0  242760.0  299453.0  372275.0
# ...

# %% [markdown]
# # included years in the data

# %%
df.Year.unique()
# Out:
# array([1978, 1976, 1979, 1977, 1975, 1967, 1985, 1983, 1986, 1982, 1973,
#        1980, 1984, 1974, 1969, 2000, 2020, 2018, 2008, 1981, 1972, 1970,
#        1971, 1994, 1987], dtype=int64)

# %% [markdown]
# #  artists included in the data

# %%
df.Artist.unique()
# Out:
# array(['A Taste Of Honey', 'ABBA', 'Andrea True Connection',
#        'Aretha Franklin', 'Ashford & Simpson', 'B.T. Express', 'Barrabas',
#        'Barry White', 'Bee Gees', 'Blue Magic', 'Bohannon', 'Boney M.',
#        'Candi Staton', 'Carol Douglas', 'Cerrone', 'Chaka Khan',
#        'Cheryl Lynn', 'CHIC', 'Claudja Barry', 'Commodores',
#        'Crown Heights Affair', 'Curtis Mayfield', 'D-Train',
#        'Dan Hartman', 'Detroit Emeralds', 'Diana Ross', 'Donna Summer',
#        'Earth, Wind & Fire', 'Ecstasy, Passion & Pain', 'Eddie Kendricks',
#        'Edwin Starr', 'Evelyn "Champagne" King', 'Fatback Band',
#        'First Choice', 'France Joli', 'G.Q.', 'Gino Soccio',
#        'Grace Jones', 'Harold Melvin & The Blue Notes', 'Heatwave',
#        'Honey Cone', 'Hues Corporation', 'Isaac Hayes', 'Jackie Moore',
#        'James Brown', 'John Davis & The Monster Orchestra',
#        'KC & The Sunshine Band', 'LaBelle', 'Lime', 'Linda Clifford',
# ...

# %% [markdown]
# # number of albums

# %%
df.Album.nunique()
# Out:
# 459

# %% [markdown]
# # most loud song

# %%
loudest_song = df.loc[df.Loudness.idxmax()]
loudest_song
# Out:
# Track                       Midnight Madness
# Artist                               Cerrone
# Album               Don Ray - Garden of Love
# Year                                    1979
# Duration                              343000
# Time_Signature                             4
# Danceability                           0.789
# Energy                                 0.932
# Key                                       11
# Loudness                              -3.384
# Mode                                       0
# Speechiness                           0.0493
# Acousticness                         0.00402
# Instrumentalness                     0.00476
# Liveness                              0.0719
# Valence                                0.886
# Tempo                                127.675
# Popularity                                 8
# Name: 114, dtype: object

# %% [markdown]
# # showing popularity over years

# %%
plt.figure(figsize=(10,5))
sns.set_style('whitegrid')
sns.lineplot(df.groupby('Year')['Popularity'].mean())
# Out:
# D:\videos\my_ds_world\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\videos\my_ds_world\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='Popularity'>

# %% [markdown]
# # top 10 popular songs

# %%
sns.set_style('whitegrid')
top_10_pop = df.sort_values(by = 'Popularity',ascending= False).head(10)
sns.barplot(  x = 'Popularity' , y = 'Track'   ,data = top_10_pop , orient= 'h' , palette='tab10')
# Out:
# <Axes: xlabel='Popularity', ylabel='Track'>

# %% [markdown]
# # top 10 most noisy songs

# %%
top_10_noisy = df.sort_values(by = 'Liveness' , ascending=False).head(10)
sns.barplot(x= 'Liveness' , y = 'Track' , data = top_10_noisy , palette='tab10')
# Out:
# <Axes: xlabel='Liveness', ylabel='Track'>

# %% [markdown]
# # top 10 clear words songs

# %%
top_10_clear = df.sort_values(by = 'Speechiness' , ascending=False).head(10)
sns.barplot(x= 'Speechiness' , y = 'Track' , data = top_10_clear , palette='tab10')
# Out:
# <Axes: xlabel='Speechiness', ylabel='Track'>

# %% [markdown]
# # top 10 danceable songs

# %%
top_10_dance = df.sort_values(by = 'Danceability' , ascending=False).head(10)
sns.barplot(x= 'Danceability' , y = 'Track' , data = top_10_dance , palette='tab10')
# Out:
# <Axes: xlabel='Danceability', ylabel='Track'>

# %% [markdown]
# # relationship between noise , danceability , clarity of words in songs and years

# %%
plt.figure(figsize=(10,5))
sns.set_style('whitegrid')
plt.plot(df.groupby('Year')['Liveness'].mean())
plt.plot(df.groupby('Year')['Speechiness'].mean())
plt.plot(df.groupby('Year')['Danceability'].mean())
plt.legend(['Liveness','Speechiness' , 'Danceability'])
plt.show()

# %% [markdown]
# # clustring using k-means algo based on danceability and energy

# %%
df
# Out:
#                                  Track            Artist  \
# 0                   Boogie Oogie Oogie  A Taste Of Honey
# 1    Disco Dancin' - 2004 - Remastered  A Taste Of Honey
# 2                              Distant  A Taste Of Honey
# 3                           Do It Good  A Taste Of Honey
# 4                          If We Loved  A Taste Of Honey
# ..                                 ...               ...
# 719                       Lady America            Voyage
# 720                     Let's Fly Away            Voyage
# 721                     Scotch Machine            Voyage
# 722                          Souvenirs            Voyage
# 723                    Tahiti, Tahiti…            Voyage
#
#                                          Album  Year  Duration  \
# 0                             A Taste Of Honey  1978    245173
# 1                             A Taste Of Honey  1978    210493
# 2                             A Taste Of Honey  1978    260053
# ...

# %%
numeric_df = df.iloc[:, [6,7]].values

# %%
numeric_df
# Out:
# array([[0.797, 0.548],
#        [0.751, 0.57 ],
#        [0.468, 0.512],
#        ...,
#        [0.633, 0.901],
#        [0.633, 0.97 ],
#        [0.672, 0.972]])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_std = scaler.fit_transform(numeric_df)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
kmeans.fit(numeric_df)
# Out:
# D:\videos\my_ds_world\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\videos\my_ds_world\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# KMeans(n_clusters=5, random_state=42)

# %%
kmeans.labels_
# Out:
# array([4, 4, 2, 1, 2, 1, 0, 0, 2, 0, 3, 2, 4, 0, 0, 3, 1, 0, 1, 0, 0, 0,
#        0, 0, 1, 3, 0, 3, 1, 2, 3, 3, 3, 4, 4, 4, 3, 1, 0, 3, 3, 4, 0, 4,
#        3, 1, 1, 0, 1, 3, 4, 4, 4, 0, 4, 1, 2, 3, 3, 2, 3, 0, 4, 2, 4, 4,
#        0, 1, 0, 1, 4, 3, 2, 2, 1, 2, 2, 2, 2, 2, 0, 2, 3, 1, 3, 3, 1, 0,
#        1, 1, 1, 1, 3, 3, 3, 1, 2, 0, 1, 3, 0, 4, 0, 2, 0, 0, 3, 4, 4, 3,
#        3, 1, 1, 1, 3, 4, 3, 3, 3, 2, 3, 1, 2, 1, 1, 1, 4, 1, 1, 1, 1, 1,
#        1, 4, 1, 1, 4, 3, 4, 4, 1, 3, 1, 2, 4, 3, 4, 2, 2, 2, 2, 1, 3, 3,
#        3, 3, 3, 1, 0, 3, 1, 3, 2, 4, 3, 4, 4, 3, 1, 4, 1, 3, 3, 3, 1, 1,
#        1, 1, 2, 4, 1, 1, 4, 1, 4, 0, 2, 2, 4, 4, 0, 3, 1, 0, 3, 1, 2, 1,
#        1, 1, 1, 1, 1, 0, 2, 0, 4, 4, 2, 3, 0, 3, 0, 1, 3, 3, 1, 4, 1, 3,
#        1, 0, 1, 0, 3, 0, 0, 2, 0, 2, 1, 3, 1, 0, 0, 1, 0, 1, 1, 4, 4, 1,
#        4, 1, 1, 1, 3, 1, 1, 4, 3, 3, 3, 0, 3, 3, 4, 1, 4, 1, 0, 1, 1, 4,
#        1, 4, 4, 2, 0, 4, 1, 1, 3, 4, 4, 4, 4, 2, 4, 4, 4, 0, 4, 3, 3, 4,
# ...

# %%
plt.figure(figsize=(10,8))
plt.scatter(numeric_df[:,0],numeric_df[:,1],c=kmeans.labels_,cmap='plasma')
plt.show()

# %%
df['class'] = kmeans.labels_

# %%
df.head(15)
# Out:
#                                           Track            Artist  \
# 0                            Boogie Oogie Oogie  A Taste Of Honey
# 1             Disco Dancin' - 2004 - Remastered  A Taste Of Honey
# 2                                       Distant  A Taste Of Honey
# 3                                    Do It Good  A Taste Of Honey
# 4                                   If We Loved  A Taste Of Honey
# 5                        Rescue Me - Remastered  A Taste Of Honey
# 6                                      Sky High  A Taste Of Honey
# 7                             This Love Of Ours  A Taste Of Honey
# 8                                    World Spin  A Taste Of Honey
# 9                                    Chiquitita              ABBA
# 10                                Dancing Queen              ABBA
# 11                                     Fernando              ABBA
# 12  Gimme! Gimme! Gimme! (A Man After Midnight)              ABBA
# ...
